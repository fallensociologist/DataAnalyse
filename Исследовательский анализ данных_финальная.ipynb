# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# <b>Привет!</b>
#
# Меня зовут Сороколетов Илья и я буду проверять твой проект.
#
# Предлагаю общаться на «**ты**», но если тебе будет комфортнее общаться на «**вы**», то сообщи об этом в комментариях)
#
#
# Для твоего удобства, я буду выделять свои комментарии следующим образом:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b> Самые важные замечания. Они указывают на ключевые моменты, которые влияют на конечный результат проекта. </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b> Советы или замечания, которые помогут сделать твою работу лучше, но необязательны к выполнению.
#
# </div>
#
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b> Так я выделяю все остальные комментарии.</div>
#
#
# Пометками <b>v1-v2-v3-...</b> я буду отмечать версию проверки. Так ты сможешь быстро найти мои новые комментарии.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения, например вот так:
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# </div>
#
# <b>Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии.</b> Если ты оставляешь свои комментарии, то делай это под моими, чтобы сообщения были расположены в хронологическом порядке. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Перед отправкой работы я рекомендую нажимать Kernel -> Restart & Run All. Это перезапустит ядро и по очереди выполнит все ячейки. Так ты сможешь проверить, что всё работает корректно. Кнопка Kernel находится в панели сверху
#
# Обязательно задавай вопросы если они возникнут, а я перехожу к проверке)
#
# P.S. На всякий случай, я оставлю пустой шаблон для твоих комментариев ниже. Кликни два раза на мой комментарий, скопируй последние четыре строчки кода и вставляй их в пустую ячейку там, где ты хочешь оставить комментарий. Не забудь только перед этим сменить тип ячейки на Markdown. Быстро это можно сделать так: кликнуть на ячейку - нажать ESC - нажать M.
#
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Удали этот текст и вместо него напиши свой комментарий 🙂
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
# <br>Перед отправкой проекта обязательно перезапускай ядро через Kernel -> Restart & Run All и проверяй, чтобы все ячейки отработали без ошибок. 103 ячейка сейчас падает с ошибкой. Поправь, пожалуйста, чтобы я смог проверить твой проект
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Готово :)
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
#импортируем pandas и читаем файл
import pandas as pd

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Все библиотеки лучше импортировать отдельно в первой ячейке. Это позволит тебе в любой момент добавить ещё одну библиотеку без перезаписи переменных.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Готово :)
# </div>

# %%
#выводим 5 первых строчек для получения общего представления о файле
display(data.head())
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Для вывода таблиц лучше использовать функцию display
# </div>

# %%
#строит гистограммы по всем столбцам
data.hist(figsize=(15, 20))
";"
# Out:
# ';'

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Графики построено верно!
# </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Если после кода вызывающего график добавить ";", то мы избавимся от строчки над графиком)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Готово!
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Здесь необходимо написать короткий вывод о проблемах с данными (пропуски, дубликаты, неверный тип данных, странные значения и т.д.)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Готово, ниже :)
# </div>

# %% [markdown]
# <b> Какие проблемы с данными были обнаружены:</b>
#
# <br>1. Большое кол-во пропущенных значений
#     2. Неверные типы данных
#
# На следующем этапе мы проверим датафрейм на наличие дубликатов и странных, выбивающихся значений

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Всё верно! Рекомендую создать универсальную функцию, которая будет на вход принимать датафрейм, а на выходе будет выводить все необходимые характеристики поочередно применяя методы head, describe, info, duplicated и т.п.
# </div>

# %% [markdown]
# ### Предобработка данных

# %%
#определяем,где присутсвуют пропуски
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
#отбираем столбцы в которых хотим заменить пропуски на 0 и меняем их
columns = ['is_apartment', 'balcony', 'parks_around3000', 'ponds_around3000']
data[columns] = data[columns].fillna(0)
#проверяем результат
print(data.head())
data.isna().sum()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8            0  ...
# 1             NaN          11.0         18.6      1            0  ...
# 2             NaN           5.0         34.3      4            0  ...
# 3             NaN          14.0          NaN      9            0  ...
# 4            3.03          14.0         32.0     13            0  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      0.0  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Пропуски в столбцах с картографическими данными лучше не трогать, так как мы не можем восстановить их с достаточной точностью. Лучше оставить их как есть.
# </div>

# %% [markdown]
# Пока что мы заменили только очевидные пропуски, далее будем производить замену по мере рассмотрения всех столбцов датафрейма подробнее

# %% [markdown]
# #### Возможные причины появления пропущенных значений
# 1. Там, где пропущенные значения были заменены, предполагалось, что владелец должен знать ответ на вопрос и если он остался без ответа, то скорее всего квартира попросту не отвечает данной характеристике
# 2. Там, где пропущенные значения не были заменены основная гипотеза их появления связана с тем, что владелец квартиры затруднился ответить на поставленный вопрос или пропустил его по какой-то иной причине

# %%
#выводим информацию по каждому столбцу
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Очевидно, что есть переменные с неподходящими типами данных, например, float в балконах, проведем замену по мере знакомства со столбцами подробнее

# %%
data.balcony = data.balcony.astype(int)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Отличная работа! Не забывай, что не всегда стоит делать замену, ради замены. Очень важно обоснование. Иногда пропуски можно удалить (если их мало), либо вообще не трогать, если у нас нет возможности подобрать аргументированный способ замены
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Ещё здесь нужно изменить тип данных в столбце balcony
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Вылезает вот такая вот ошибка при попытке замены типа переменной - "Cannot convert non-finite values (NA or inf) to integer"
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v2:</b>
# <br>Вот такой код сработал
#
#     data.balcony = data.balcony.astype(int)
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v3:</b>
# <br>Правка не выполнена
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Сделал это выше
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v4:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# #### Оставить только уникальные значения в названиях

# %%
#Изучаем уникальные значения в столбце с названиями
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
#проверим столбец на пропуски
data['locality_name'].isna().sum()
# Out:
# 49

# %% [markdown]
# Так как таких строк не много, относительно общего массива, мы можем ими пренебречь

# %%
#удаляем пропуски из столбца с названиями населенных пунктов
data = data[data['locality_name'].isna()==False].reset_index(drop=True)
data['locality_name'].isna().sum()
# Out:
# 0

# %% [markdown]
# Готово, переходим к поиску дубликатов
#
# Для начала приведем все к одному регистру

# %%
data['locality_name'] = data['locality_name'].str.lower()
len(data['locality_name'].unique())
# Out:
# 364

# %% [markdown]
# Видим, что где-то используется ё, а где-то е, избавимся от этого

# %%
for i in range(len(data['locality_name'])):
    if 'ё' in data['locality_name'][i]:
        data.loc[i, 'locality_name'] = data['locality_name'][i].replace('ё','е')
data['locality_name'].unique()
# Out:
# array(['санкт-петербург', 'поселок шушары', 'городской поселок янино-1',
#        'поселок парголово', 'поселок мурино', 'ломоносов', 'сертолово',
#        'петергоф', 'пушкин', 'деревня кудрово', 'коммунар', 'колпино',
#        'поселок городского типа красный бор', 'гатчина',
#        'деревня федоровское', 'выборг', 'кронштадт', 'кировск',
#        'деревня новое девяткино', 'поселок металлострой',
#        'поселок городского типа лебяжье',
#        'поселок городского типа сиверский', 'поселок молодцово',
#        'поселок городского типа кузьмоловский',
#        'садовое товарищество новая ропша', 'павловск',
#        'деревня пикколово', 'всеволожск', 'волхов', 'кингисепп',
#        'приозерск', 'сестрорецк', 'деревня куттузи', 'поселок аннино',
#        'поселок городского типа ефимовский', 'поселок плодовое',
#        'деревня заклинье', 'поселок торковичи', 'поселок первомайское',
#        'красное село', 'поселок понтонный', 'сясьстрой', 'деревня старая',
# ...

# %% [markdown]
# Теперь попробуем избавиться от наименований внаселенных пунктов

# %%
data['good_locality_name'] = data['locality_name']
extra_name=['деревня ', 'поселок ', 'городской ', 'городского типа ', 'садовое товарищество ', 'село ', 'коттеджный поселок ', 'садоводческое некоммерческое товарищество', 'при железнодорожной станции', 'коттеджный', 'станции ', 'пансионат']
for i in extra_name:
    data['good_locality_name'] = data['good_locality_name'].str.replace(i, '')
len(data['good_locality_name'].unique())
# Out:
# 308

# %%
data['good_locality_name'].unique()
# Out:
# array(['санкт-петербург', 'шушары', 'янино-1', 'парголово', 'мурино',
#        'ломоносов', 'сертолово', 'петергоф', 'пушкин', 'кудрово',
#        'коммунар', 'колпино', 'красный бор', 'гатчина', 'федоровское',
#        'выборг', 'кронштадт', 'кировск', 'новое девяткино',
#        'металлострой', 'лебяжье', 'сиверский', 'молодцово',
#        'кузьмоловский', 'новая ропша', 'павловск', 'пикколово',
#        'всеволожск', 'волхов', 'кингисепп', 'приозерск', 'сестрорецк',
#        'куттузи', 'аннино', 'ефимовский', 'плодовое', 'заклинье',
#        'торковичи', 'первомайское', 'красное село', 'понтонный',
#        'сясьстрой', 'старая', 'лесколово', 'новый свет', 'сланцы',
#        'путилово', 'ивангород', 'шлиссельбург', 'никольское',
#        'зеленогорск', 'сосновый бор', 'оржицы', 'кальтино', 'романовка',
#        'бугры', 'рощино', 'кириши', 'луга', 'волосово', 'отрадное',
#        'павлово', 'оредеж', 'копорье', 'молодежное', 'тихвин', 'победа',
# ...

# %% [markdown]
# Готово, избавились от 56 дубликатов

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Супер! Здесь всё верно)
# </div>

# %% [markdown]
# #### Ищем и устраняем редкие и выбивающиеся значения
# Для этого пройдемся по всем столбцам с числовыми значениями

# %% [markdown]
# ##### ceiling_height

# %%
data['ceiling_height'].unique()
# Out:
# array([  2.7 ,    nan,   3.03,   2.5 ,   2.67,   2.56,   3.05,   2.75,
#          2.6 ,   2.9 ,   2.8 ,   2.55,   3.  ,   2.65,   3.2 ,   2.61,
#          3.25,   3.45,   2.77,   2.85,   2.64,   2.57,   4.15,   3.5 ,
#          3.3 ,   2.71,   4.  ,   2.47,   2.73,   2.84,   3.1 ,   2.34,
#          3.4 ,   3.06,   2.72,   2.54,   2.51,   2.78,   2.76,  25.  ,
#          2.58,   3.7 ,   2.52,   5.2 ,   2.87,   2.66,   2.59,   2.  ,
#          2.45,   3.6 ,   2.92,   3.11,   3.13,   3.8 ,   3.15,   3.55,
#          3.16,   3.62,   3.12,   2.53,   2.74,   2.96,   2.46,   5.3 ,
#          5.  ,   2.79,   2.95,   4.06,   2.94,   3.82,   3.54,   3.53,
#          2.83,   4.7 ,   2.4 ,   3.38,   3.01,   5.6 ,   3.65,   3.9 ,
#          3.18,   3.35,   2.3 ,   3.57,   2.48,   2.62,   2.82,   3.98,
#          2.63,   3.83,   3.52,   3.95,   3.75,   2.88,   3.67,   3.87,
#          3.66,   3.85,   3.86,   4.19,   3.24,   4.8 ,   4.5 ,   4.2 ,
# ...

# %% [markdown]
# Видим странные значения: 14, 25 и даже 100 метров! Посмотрим сколько их с помощью гистограмм

# %%
data['ceiling_height'].hist(bins=100, range=(0,101))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видим, что основная масса значений расположена ближе к 0, посмотрим ближе

# %%
data['ceiling_height'].hist(bins=100, range=(0,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Жизненный опыт подсказывает, что потолки не должны быть менее 2,5 метров, посмотрим сколько таких и при необходимости удалим
#
# А вот еще взял из ЦИАН - "В своде правил установлено, что в многоквартирных домах в центральной части России потолок должен быть не ниже 2,5 м, а в Сибири, на Дальнем Востоке и на севере Центральной России — не ниже 2,7 м."

# %%
data['ceiling_height'].hist(bins=100, range=(0,2.49))
len(data.query('ceiling_height < 2.5'))
# Out:
# 73

# %% [markdown]
# Таких значений не так много, предлагаю избавляться

# %%
data = (data.drop(index=data[(data['ceiling_height'] < 2.5) ].index).reset_index(drop=True))
len(data.query('ceiling_height < 2.5'))
# Out:
# 0

# %% [markdown]
# Теперь взгляним на потолки выше 4 метров

# %%
data['ceiling_height'].hist(bins=100, range=(4,101))
len(data.query('ceiling_height >= 4'))
# Out:
# 113

# %% [markdown]
# Многовато, а 4 метра выглядит не таким редким значением

# %%
data['ceiling_height'].hist(bins=100, range=(5,101))
len(data.query('ceiling_height >= 5'))
# Out:
# 37

# %% [markdown]
# Предлагаю удалять

# %%
data = (data.drop(index=data[(data['ceiling_height'] >= 5) ].index).reset_index(drop=True))
len(data.query('ceiling_height >= 5'))
# Out:
# 0

# %%
data['ceiling_height'].isna().sum()
# Out:
# 9160

# %% [markdown]
# В переменной остается много пропусков, попробуем понять на основании какого показателя их можно заполнить. Воспользуемся зависимостями (correlations)

# %%
data.corr()['ceiling_height'].sort_values(ascending=False)
# Out:
# ceiling_height         1.000000
# total_area             0.481154
# living_area            0.458367
# kitchen_area           0.417486
# last_price             0.388363
# rooms                  0.301080
# parks_around3000       0.297450
# ponds_around3000       0.269906
# days_exposition        0.132021
# total_images           0.042923
# open_plan              0.012750
# studio                 0.009198
# floor                 -0.049348
# parks_nearest         -0.058184
# balcony               -0.077045
# floors_total          -0.096327
# airports_nearest      -0.106074
# ponds_nearest         -0.146299
# cityCenters_nearest   -0.371200
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Наибольшая корреляция наблюдается со значением общей площади. Тем не менее она составляет менее 0,5, поэтому предлагается не заменять значения в пропусках.

# %% [markdown]
# ##### floors_total

# %%
data['floors_total'].unique()
# Out:
# array([16., 11.,  5., 14., 12., 26., 24., 27.,  9.,  6., 17., 25.,  3.,
#        23., 19., 18.,  4., 22.,  8.,  2., 10.,  7., 13., 15., nan, 20.,
#        28., 36., 21., 35., 34., 60.,  1., 29., 33., 52.])

# %%
# посмотрим на кол-во пропусков
data['floors_total'].isna().sum()
# Out:
# 85

# %%
# для поиска идей, что с этим делать, обратимся к floor
data['floor'].isna().sum()
# Out:
# 0

# %%
# в столбце нет пропусков, предлагаю отталкиваться от идеи, что каждый пропуск в общем кол-ве этажей равен фактическому этажу, на котором расположена квартира
data['floors_total'] = data['floors_total'].fillna(data['floor'])
data['floor'].isna().sum()
# Out:
# 0

# %%
#заменим тип данных и еще раз проверим уникальные значения
data['floors_total'] = data['floors_total'].astype('int')
data['floors_total'].unique()
# Out:
# array([16, 11,  5, 14, 12, 26, 24, 27,  9,  6, 17, 25,  3, 23, 19, 18,  4,
#        22,  8,  2, 10,  7, 13, 15,  1, 20, 28, 36, 21, 35, 34, 60, 29, 33,
#        52])

# %% [markdown]
# ##### total_area

# %%
data['total_area'].describe()
# Out:
# count    23540.000000
# mean        60.334130
# std         35.573782
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %%
data['total_area'].isna().sum()
# Out:
# 0

# %%
len(data[data['total_area'] <= 20])
# Out:
# 35

# %%
len(data[data['total_area'] >= 400])
# Out:
# 26

# %% [markdown]
# Удалим объявления со слишком большой и слишком маленькой жилой площадью

# %%
data = (data.drop(index=data[(data['total_area'] <= 20)].index).reset_index(drop=True))
data = (data.drop(index=data[(data['total_area'] >= 400)].index).reset_index(drop=True))

# %%
data['total_area'].describe()
# Out:
# count    23479.000000
# mean        59.915587
# std         32.292889
# min         20.100000
# 25%         40.000000
# 50%         52.000000
# 75%         69.705000
# max        398.000000
# Name: total_area, dtype: float64

# %% [markdown]
# ##### rooms

# %%
data['rooms'].unique()
# Out:
# array([ 3,  1,  2,  4,  5,  6,  0,  7, 11,  8, 14, 10,  9, 19, 16])

# %%
#давайте глянем на распределение
data['rooms'].hist(bins=100, range=(0,20))
# Out:
# <AxesSubplot:>

# %%
#проверим насколько провдоподобны данные по наиболее крупным лотам (от 8 комнат)
data[data['rooms'] >= 10]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 642               3  17500000.0       183.7  2018-07-01T00:00:00     11
# 858               5  25000000.0       363.0  2017-12-23T00:00:00     14
# 4119              6  23000000.0       272.6  2018-01-11T00:00:00     10
# 9603              8  33000000.0       194.1  2017-02-07T00:00:00     11
# 14375             6  32250000.0       374.6  2018-06-09T00:00:00     19
# 17964             4  15500000.0       216.1  2016-07-04T00:00:00     10
# 18691             6  28500000.0       270.0  2015-03-02T00:00:00     16
# 18734            11  40000000.0       290.0  2016-06-21T00:00:00     10
# 20645             6  28659000.0       245.4  2016-03-31T00:00:00     14
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 642              3.40             7        138.8      7            0  ...
# 858              3.16             5        222.0      4            0  ...
# ...

# %%
data['rooms'].isna().sum()
# Out:
# 0

# %% [markdown]
# Предлагаю удалить выделяющиеся значения (больше 9 комнат)
#
# Пропуски отсутствуют

# %%
data = (data.drop(index=data[(data['rooms'] >= 10)].index).reset_index(drop=True))

# %%
data['living_area'].isna().sum()
# Out:
# 1871

# %% [markdown]
# Очень много пропусков, надо с этим что-то делать.
#
# Рискну предположить, что большая зависимость присутсвует между общей площадью и жилой. Проверим! Если это так, то будем ориентироваться на значения общей площади для восстановления пропущенных значений!

# %%
data.corr()['living_area'].sort_values(ascending=False)
# Out:
# living_area            1.000000
# total_area             0.934801
# rooms                  0.857098
# last_price             0.601667
# ceiling_height         0.460586
# kitchen_area           0.394027
# parks_around3000       0.217074
# ponds_around3000       0.187173
# days_exposition        0.149172
# total_images           0.106976
# balcony               -0.016138
# open_plan             -0.034160
# parks_nearest         -0.052678
# studio                -0.058329
# airports_nearest      -0.060712
# ponds_nearest         -0.077345
# floor                 -0.107202
# floors_total          -0.176663
# cityCenters_nearest   -0.234911
# Name: living_area, dtype: float64

# %%
#найдем среднюю долю жилой площади от общей
(data['living_area'] / data['total_area']).mean()
# Out:
# 0.5642904488708647

# %%
#воспользуемся полученным коэффициентом для восстановаления пропущенных значений
data['living_area'] = data['living_area'].fillna(0.56 * data['total_area'])

# %%
data['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Победа! Пропуски заменили средним значением другой переменной
# Возможно стоило учесть влияние других переменных, но был выбран наиболее простой путь

# %% [markdown]
# ##### kitchen_area

# %%
data['kitchen_area'].isna().sum()
# Out:
# 2219

# %%
data.corr()['kitchen_area'].sort_values(ascending=False)
# Out:
# kitchen_area           1.000000
# total_area             0.593165
# last_price             0.526712
# ceiling_height         0.418421
# living_area            0.397667
# rooms                  0.245618
# ponds_around3000       0.176390
# floors_total           0.170721
# floor                  0.137497
# parks_around3000       0.119531
# days_exposition        0.104114
# total_images           0.104038
# balcony                0.048465
# parks_nearest          0.030033
# airports_nearest       0.008117
# ponds_nearest         -0.101606
# cityCenters_nearest   -0.189673
# studio                      NaN
# open_plan                   NaN
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Корреляции показывают, что площадь кухни больше всего зависит от общей площади квартиры. В целом это оправдано, так как кухня не входит в жилую площадь, относясь к нежилой.

# %%
#найдем среднюю долю кухни от общей площади
(data['kitchen_area'] / data['total_area']).mean()
# Out:
# 0.18759929167120487

# %%
data['kitchen_area'] = data['kitchen_area'].fillna(0.19*data['total_area'])
data['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# ##### airports_nearest

# %%
data['airports_nearest'].isna().sum()
# Out:
# 5480

# %%
data['airports_nearest'].describe()
# Out:
# count    17990.000000
# mean     28820.664036
# std      12648.181910
# min          0.000000
# 25%      18557.000000
# 50%      26770.000000
# 75%      37344.750000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %% [markdown]
# ##### cityCenters_nearest

# %%
data['cityCenters_nearest'].isna().sum()
# Out:
# 5459

# %%
data['cityCenters_nearest'].describe()
# Out:
# count    18011.000000
# mean     14220.125368
# std       8602.838885
# min        181.000000
# 25%       9289.000000
# 50%      13123.000000
# 75%      16297.000000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# ##### parks_nearest

# %%
data['parks_nearest'].isna().sum()
# Out:
# 15482

# %%
data['parks_nearest'].describe()
# Out:
# count    7988.000000
# mean      491.216450
# std       343.608137
# min         1.000000
# 25%       288.000000
# 50%       454.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# ##### ponds_nearest

# %%
data['ponds_nearest'].isna().sum()
# Out:
# 14462

# %%
data['ponds_nearest'].describe()
# Out:
# count    9008.000000
# mean      518.761656
# std       277.680069
# min        13.000000
# 25%       294.000000
# 50%       503.000000
# 75%       731.000000
# max      1344.000000
# Name: ponds_nearest, dtype: float64

# %% [markdown]
# ##### days_exposition

# %%
data['days_exposition'].isna().sum()
# Out:
# 3153

# %%
data['days_exposition'].describe()
# Out:
# count    20317.000000
# mean       180.891027
# std        219.827929
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Переменные 2.3.6-2.3.10 имеют большое количество пропусков, но кажется, что заполнить их нечем. Не логичности в данных отсутствуют

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Давай всё же отбросим аномалии в некоторых столбцах. Посмотри какие значения есть в столбцах со стоимостью квартиры, количеством комнат и общей площадью. В них есть значения, которые сильно выделяются на общем фоне (аномально высокие). Не забудь проверить какое количество данных мы в итоге отбрасываем. Это количество не должно превышать 10% от изначального объёма данных. C этим может помочь следующий код
#
# 	new_data.shape[0] / old_data.shape[0]
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>С переменными кол-во комнат и общая площадь поработал выше, со стоимостью в следующем разделе
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v3:</b>
# <br>Отлично! Теперь всё верно)
# </div>

# %% [markdown]
# # Другие столбцы
#
# В столбцах floor, is_apartment, open_plan, studio, balcony, parks_around3000 и ponds_around3000 не было пропущенных значений, либо они были заменены в самом начале, не будет останавливаться на них подробее

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# #### Цена за метр

# %%
data['last_price'].describe()
# Out:
# count    2.347000e+04
# mean     6.378431e+06
# std      8.120282e+06
# min      1.219000e+04
# 25%      3.440000e+06
# 50%      4.650000e+06
# 75%      6.790000e+06
# max      3.300000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Подобный формат данных сильно затрудняет их восприятие, попробуем разделить на млн.

# %%
data['last_price_good'] = data['last_price'] / 1000000
data['last_price_good'].describe()
# Out:
# count    23470.000000
# mean         6.378431
# std          8.120282
# min          0.012190
# 25%          3.440000
# 50%          4.650000
# 75%          6.790000
# max        330.000000
# Name: last_price_good, dtype: float64

# %%
data['last_price_good'].hist(bins=100, range=(100,330))
# Out:
# <AxesSubplot:>

# %%
len(data[data['last_price_good'] > 100])
# Out:
# 25

# %% [markdown]
# Удалим предложения дороже 100 миллионов рублей

# %%
data = (data.drop(index=data[(data['last_price_good'] >= 100)].index).reset_index(drop=True))

# %%
data['price_metr'] = data['last_price_good'] / data['total_area']
data['price_metr'].describe()
# Out:
# count    23445.000000
# mean         0.098580
# std          0.042903
# min          0.000112
# 25%          0.076667
# 50%          0.095000
# 75%          0.114078
# max          0.848485
# Name: price_metr, dtype: float64

# %% [markdown]
# Умножим полученное значение на 1000, чтобы получить значение тыс. рублей за квадратный метр

# %%
data['price_metr_good'] = data['price_metr'] * 1000
data['price_metr_good'].describe()
# Out:
# count    23445.000000
# mean        98.580030
# std         42.903104
# min          0.111835
# 25%         76.666667
# 50%         95.000000
# 75%        114.077670
# max        848.484848
# Name: price_metr_good, dtype: float64

# %% [markdown]
# #### День, месяц, год публикации

# %% [markdown]
# Для начала приведем дату к корректному формату

# %%
data['date'] = pd.to_datetime(data['first_day_exposition'], format='%Y.%m.%dT%H:%M:%S')
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16        51.00      8            0  ...
# 1             NaN            11        18.60      1            0  ...
# 2             NaN             5        34.30      4            0  ...
# 3             NaN            14        89.04      9            0  ...
# 4            3.03            14        32.00     13            0  ...
#
#    parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# ...

# %% [markdown]
# Создадим три новых столбца

# %%
data['day'] = pd.DatetimeIndex(data['date']).day
data['month'] = pd.DatetimeIndex(data['date']).month
data['year'] = pd.DatetimeIndex(data['date']).year
data['weekday'] = pd.DatetimeIndex(data['date']).weekday
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16        51.00      8            0  ...
# 1             NaN            11        18.60      1            0  ...
# 2             NaN             5        34.30      4            0  ...
# 3             NaN            14        89.04      9            0  ...
# 4            3.03            14        32.00     13            0  ...
#
#    days_exposition  good_locality_name  last_price_good  price_metr  \
# ...

# %% [markdown]
# #### Тип этажа

# %%
def floor_type(data):
    if data['floor'] == 1:
        data['floor_type'] = 'первый'
    elif data['floor'] == data['floors_total']:
        data['floor_type'] = 'последний'
    else:
        data['floor_type'] = 'другой'
    return data

# %%
data = data.apply(floor_type, axis=1)
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16        51.00      8            0  ...
# 1             NaN            11        18.60      1            0  ...
# 2             NaN             5        34.30      4            0  ...
# 3             NaN            14        89.04      9            0  ...
# 4            3.03            14        32.00     13            0  ...
#
#    good_locality_name  last_price_good  price_metr  price_metr_good  \
# ...

# %% [markdown]
# Новый столбец с типом этажа добавлен

# %% [markdown]
# #### Расстояние до центра в км

# %%
data['cityCenters_nearest_km'] = (data['cityCenters_nearest'] / 1000).round(0)
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16        51.00      8            0  ...
# 1             NaN            11        18.60      1            0  ...
# 2             NaN             5        34.30      4            0  ...
# 3             NaN            14        89.04      9            0  ...
# 4            3.03            14        32.00     13            0  ...
#
#    last_price_good  price_metr  price_metr_good       date day  month  year  \
# ...

# %% [markdown]
# Новый столбец добавлен, значения округлены до целых

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Все необходимые колонки добавлены. Идём дальше)
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# Построим графики по всем интересующим нас переменным

# %%
data.loc[:,['total_area', 'living_area', 'kitchen_area', 'last_price_good', 'rooms','ceiling_height', 'floor', 'floor_type', 'floor_type', 'cityCenters_nearest', 'airports_nearest', 'parks_nearest', 'day', 'month']].hist(figsize=(10,10), bins=50)
";"
# Out:
# ';'

# %% [markdown]
# На большинство переменных нужно взглянуть поближе как мы делали ранее, когда работали с заменой пустых значений
#
# Комментарии к каждому из графиков будут представлены ниже

# %%
data['total_area'].hist(bins=100, range=(0,200))
data['total_area'].describe()
# Out:
# count    23445.000000
# mean        59.632466
# std         31.364967
# min         20.100000
# 25%         40.000000
# 50%         52.000000
# 75%         69.500000
# max        398.000000
# Name: total_area, dtype: float64

# %%
data['total_area'].mode()
# Out:
# 0    45.0
# dtype: float64

# %%
data['total_area'].median()
# Out:
# 52.0

# %%
data['living_area'].hist(bins=100, range=(0,200))
data['living_area'].describe()
# Out:
# count    23445.000000
# mean        34.111042
# std         20.066329
# min          2.000000
# 25%         19.000000
# 50%         30.000000
# 75%         42.000000
# max        255.700000
# Name: living_area, dtype: float64

# %%
data['living_area'].mode()
# Out:
# 0    18.0
# dtype: float64

# %%
data['living_area'].median()
# Out:
# 30.0

# %%
data['kitchen_area'].hist(bins=100, range=(0,100))
data['kitchen_area'].describe()
# Out:
# count    23445.000000
# mean        10.517102
# std          5.755262
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        107.000000
# Name: kitchen_area, dtype: float64

# %%
data['kitchen_area'].mode()
# Out:
# 0    6.0
# dtype: float64

# %%
data['kitchen_area'].median()
# Out:
# 9.1

# %%
data['last_price_good'].hist(bins=100, range=(0,100))
data['last_price_good'].describe()
# Out:
# count    23445.000000
# mean         6.218174
# std          6.233950
# min          0.012190
# 25%          3.435000
# 50%          4.650000
# 75%          6.750000
# max         99.000000
# Name: last_price_good, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Разделить все значения на 1 млн - хорошее решение
# </div>

# %%
data['last_price_good'].mode()
# Out:
# 0    4.5
# dtype: float64

# %%
data['last_price_good'].median()
# Out:
# 4.65

# %%
data['rooms'].hist(bins=20, range=(0,10))
data['rooms'].describe()
# Out:
# count    23445.000000
# mean         2.060439
# std          1.039309
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          9.000000
# Name: rooms, dtype: float64

# %%
data['rooms'].median()
# Out:
# 2.0

# %%
data['ceiling_height'].hist(bins=100, range=(2,5))
data['ceiling_height'].describe()
# Out:
# count    14321.000000
# mean         2.724598
# std          0.265918
# min          2.500000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max          4.800000
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].mode()
# Out:
# 0    2.5
# dtype: float64

# %%
data['ceiling_height'].median()
# Out:
# 2.65

# %%
data['floor'].hist(bins=100, range=(1,100))
data['floor'].describe()
# Out:
# count    23445.000000
# mean         5.904500
# std          4.889642
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64

# %%
data['floor'].mode()
# Out:
# 0    2
# dtype: int64

# %%
data['floor'].median()
# Out:
# 4.0

# %%
data['floor_type'].value_counts()
# Out:
# другой       17207
# последний     3362
# первый        2876
# Name: floor_type, dtype: int64

# %%
data['floors_total'].hist(bins=100, range=(1,100))
data['floors_total'].describe()
# Out:
# count    23445.000000
# mean        10.700533
# std          6.596890
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %%
data['floors_total'].mode()
# Out:
# 0    5
# dtype: int64

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Не хватает графика для столбца floors_total
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>График добавлен
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v2:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# #### Тип этажа

# %%
data['cityCenters_nearest'].hist(bins=100, range=(100,60000))
data['cityCenters_nearest'].describe()
# Out:
# count    17986.000000
# mean     14234.549705
# std       8599.702766
# min        181.000000
# 25%       9324.500000
# 50%      13138.000000
# 75%      16304.500000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %%
data['cityCenters_nearest'].median()
# Out:
# 13138.0

# %%
data['airports_nearest'].hist(bins=100, range=(8000,60000))
data['airports_nearest'].describe()
# Out:
# count    17965.000000
# mean     28825.160312
# std      12655.462703
# min          0.000000
# 25%      18551.000000
# 50%      26781.000000
# 75%      37351.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %%
data['airports_nearest'].median()
# Out:
# 26781.0

# %%
data['parks_nearest'].hist(bins=100, range=(0,4000))
data['parks_nearest'].describe()
# Out:
# count    7966.000000
# mean      491.518453
# std       343.892512
# min         1.000000
# 25%       288.000000
# 50%       454.500000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %%
data['parks_nearest'].mode()
# Out:
# 0    441.0
# dtype: float64

# %%
data['day'].hist(bins=50, range=(0,32))
data['day'].describe()
# Out:
# count    23445.000000
# mean        15.477159
# std          8.643978
# min          1.000000
# 25%          8.000000
# 50%         15.000000
# 75%         23.000000
# max         31.000000
# Name: day, dtype: float64

# %%
data['weekday'].hist(bins=50, range=(0,8))
data['weekday'].describe()
# Out:
# count    23445.000000
# mean         2.568394
# std          1.787886
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          4.000000
# max          6.000000
# Name: weekday, dtype: float64

# %%
data['weekday'].mode()
# Out:
# 0    3
# dtype: int64

# %%
data['month'].hist(bins=50, range=(0,12))
data['month'].describe()
# Out:
# count    23445.000000
# mean         6.402644
# std          3.491398
# min          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%         10.000000
# max         12.000000
# Name: month, dtype: float64

# %%
data['month'].mode()
# Out:
# 0    2
# dtype: int64

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Тут необходимо изучить день недели и месяц. Мы как раз создали столбцы для них в предыдущем шаге
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Графики добавил, комментарий будет добавлен ниже, к общему комментарию
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v3:</b>
# <br>Правка выполнена 👍
# </div>

# %% [markdown]
# #### Общий комментарий
# 1. Наиболее популярное значение общей площади равно 45 метрам. Медианным значением является 52 метра, что означает, что половина площадей из всех объявлений меньше этого значения, а вторая половина больше
# 2. Чаще всего жилой площади отводится лишь 18 метров. Однако в половине объявлений данная площадь составляет более 30 метров
# 3. Наиболее распространенная площадь кухни в наших объявлениях - всего 6 квадратных метров. Половина объвялений может похвастаться кухней больше 9 метров
# 4. Самая распространенная стоимость квартиры - 4,5 миллиона рублей. Ровно половина объявлений стоит не дороже 4,65 миллионов рублей, другая половина, соответственно, стоит дороже
# 5. Чаще всего в объявлениях встречаются 1-комнатные квартиры. Лишь в половине объявлений количество комнат больше 2.
# 6. Наиболее частая высота потолка в квартирах из наших объявлений - 2,5 метра. Половина всех объявлений имеет потолки не выше 2,65 метра.
# 7. Чаще всего в объявлениях встречаются квартиры, располагаемые на втором этаже. Целая половина квартир из объявлений располагается не выше 4 этажа. Очень интересная закономерность. Возможно в нашей базе есть большой перекос в сторону 5-этажек
# 8. Подавляющее большинство квартир из объявлений располагается не на первом и не на последнем этажах. При этом количество квартир, располагаемых на последнем этаже больше, чем на первом
# 9. Так и есть, в нашей выборке чаще других встречаются объявления о продаже квартир в 5-тиэтажках
# 9. Половина квартир располагаются на расстоянии 13,1 км от центра. Другая половина имеет большее отдаление
# 10. Значения по отдаленности квартиры от аэропорта выглядят вполне логично. Большинство квартира удалены от аэропорта на расстояние не менее 18,5 км.
# 11. Довольно интересным является тот факт, что большинство квартир располагается в пределах 600 метров от парка. Действительно пешая доступность. Я и не догадывался, что в нашей стороне такая хорошая обеспеченность парками... Или же мы имеем дело с довольно специфичной выборкой.
# 12. Чаще всего сообщения публиковались в самом начале месяца - первого числа, а также 10го. Реже всего новые объявления появлялись 30 и 31. Это неудивительно, ведь 30ое число встречает только 11 раз в году, а 31ое и вовсе лишь 7.
# 13. Самый популярный день недели для публикации - четверг, месяц - февраль
# 13. Наибольшее количество публикаций объявлений осуществлялось с февраля по апрель, а также в октябре и ноябре. В каждый из этих месяцев публиковались более 2 000 предложений о продаже

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Ты корректно подбираешь основные диапазоны, а также верно читаешь графики, но...
# </div>
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>...после того как ты внесёшь правки в предыдущем разделе, то выводы могут изменится. Обязательно перепроверь их
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Выводы дополнил. Основные показатели практически не поменялись после удаления выбивающихся значений
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v3:</b>
# <br>Ты корректно подбираешь основные диапазоны, а также верно читаешь графики!
# </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v3:</b>
# <br>Для того чтобы подписать график мы можем использовать метод plt.title() и в конце кода применить plt.show(). По ссылкам ниже можно почитать подробнее как добавить название для графика или подписать его оси
#
#     https://pyprog.pro/mpl/mpl_title.html
#     https://pyprog.pro/mpl/mpl_axis_signatures.html
# </div>

# %% [markdown]
# #### Типичная квартира в выборке
#
# Продается 1-комнатная квартира на втором этаже 5-ти этажного жилого дома. Площадь - 45 метров, из них 6 метров отводится кухне и 18 метров на жилую площадь. Доступная цена - 4,5 миллиона рублей. Потолки 2,5 метра.
#
# Расстояние до центра города чуть больше 13 км. До ближайшего парка всего 441 метр. Улететь в другой город вы сможете, проделав путь чуть более 14,5 км.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Ты не изучил как быстро продавались квартиры (шаг 4.2 по брифу)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Сделаю это следующим пунктом
# </div>

# %% [markdown]
# #### Скорость продажи квартир

# %%
data['days_exposition'].hist(bins=50, range=(0,1580))
data['days_exposition'].describe()
# Out:
# count    20294.000000
# mean       180.640928
# std        219.620131
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data['days_exposition'].mode()
# Out:
# 0    45.0
# dtype: float64

# %%
data['days_exposition'].median()
# Out:
# 95.0

# %%
data['days_exposition'].mean()
# Out:
# 180.64092835320784

# %% [markdown]
# Наиболее распространенный случай - продажа объекта происходит спустя 45 дней после размещения объявления. Вместе с тем, лишь половина объектов продается за 95 дней, а среднее кол-во дней актвности объявления и вовсле практически в два раза выше - 181 день.
#
# Быстрыми могут считаться продажи, входящие в первый квартиль - менее 45 дней для продажи. Долгие - 4 квартиль, более 231 дня на доске объявлений.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v3:</b>
# <br>Согласен! Если интересно, то можно посмотреть на диапазон от 0 до 100 дней. Там есть пики, которым можно найти очень логичное объяснение</div>
# </div>

# %% [markdown]
# #### Изучение факторов, влияющих на стоимость объектов

# %% [markdown]
# Для начала посмотрим на коэффициент корреляции

# %%
data[['last_price_good', 'total_area', 'rooms', 'living_area', 'kitchen_area', 'floor', 'weekday', 'month', 'year']].corr()
# Out:
#                  last_price_good  total_area     rooms  living_area  \
# last_price_good         1.000000    0.760882  0.463151     0.675912
# total_area              0.760882    1.000000  0.780524     0.939013
# rooms                   0.463151    0.780524  1.000000     0.848537
# living_area             0.675912    0.939013  0.848537     1.000000
# kitchen_area            0.607597    0.634470  0.301153     0.450369
# floor                   0.035903   -0.031613 -0.157209    -0.100497
# weekday                -0.005108   -0.009772 -0.005955    -0.008072
# month                   0.010147    0.010652 -0.001405     0.005443
# year                   -0.052755   -0.084667 -0.053147    -0.074755
#
#                  kitchen_area     floor   weekday     month      year
# last_price_good      0.607597  0.035903 -0.005108  0.010147 -0.052755
# total_area           0.634470 -0.031613 -0.009772  0.010652 -0.084667
# rooms                0.301153 -0.157209 -0.005955 -0.001405 -0.053147
# ...

# %% [markdown]
# Наибольшая корреляция у цены объекта наблюдается с общей площадью (0,76), жилой площадью (0,68), площадью кухни (0,61) и кол-ом комнат (0,46). Этаж и месяц оказывают еле заметное положительное влияние, день недели и год - очень слабое отрицательное

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Тут можно построить компактную табличку выбрав все необходимые столбцы и применив к ним corr()
#
# 	df[['last_price', 'total_area', 'rooms', '...']].corr()
# </div>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Влияние общей площади на стоимость

# %%
data.plot(kind = 'scatter', y='last_price_good', x='total_area', alpha=0.05)
plt.ylim(0,15)
plt.xlim(20,150)
# Out:
# (20.0, 150.0)

# %% [markdown]
# На графике видим подтверждение результатов корреляционного анализа - выраженная положительная зависимость между общей площадь и стоимостью квартиры

# %% [markdown]
# ##### Влияние жилой площади на стоимость

# %%
data.plot(kind = 'scatter', y='last_price_good', x='living_area', alpha=0.05)
plt.ylim(0,15)
plt.xlim(10,100)
# Out:
# (10.0, 100.0)

# %% [markdown]
# Зависимость менее отчетлива, но все же заметна. Многие люди пользуются перепланировками, что позволяет при необходимости расширить жилую площадь, например, объединив кухню с комнатой. Возможно это является одной из причин менее выраженного влияния рассматриваемого фактора

# %% [markdown]
# ##### Влияние площади кухни на стоимость

# %%
data.plot(kind = 'scatter', y='last_price_good', x='kitchen_area', alpha=0.05)
plt.ylim(0,15)
plt.xlim(0,40)
# Out:
# (0.0, 40.0)

# %% [markdown]
# Ситуация похожа на жилую площадь, зависимость есть, но заметно ниже, чем в случае с общей площадью

# %% [markdown]
# ##### Влияние высоты потолков на стоимость

# %%
data.plot(kind = 'scatter', y='last_price_good', x='ceiling_height', alpha=0.05)
plt.ylim(0,15)
plt.xlim(2,6)
# Out:
# (2.0, 6.0)

# %% [markdown]
# ##### Влияние кол-ва комнат на стоимость

# %%
data.plot(kind = 'scatter', y='last_price_good', x='rooms', alpha=0.05)
plt.ylim(0,15)
plt.xlim(0,10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# Связь слабая, но тем не менее мы видим, что с увеличением кол-ва комнат все сложнее найти бюджетный вариант жилья

# %% [markdown]
# ##### Влияние удаленности от центра на стоимость

# %%
data.plot(kind = 'scatter', y='last_price_good', x='cityCenters_nearest_km', alpha=0.05)
plt.ylim(0,15)
plt.xlim(0,30)
# Out:
# (0.0, 30.0)

# %% [markdown]
# После преодаления отметки в 20 км от центра, все реже встречаются объявления о продаже дороже 10 миллионов

# %% [markdown]
# ##### Влияние этажа на стоимость

# %%
data_floor = data.pivot_table(values='last_price_good', index = 'floor_type',aggfunc='median')
data_floor.plot(kind='bar')
plt.ylabel('median_price')
# Out:
# Text(0, 0.5, 'median_price')

# %% [markdown]
# Наиболее высокая средняя стоимость квартиры заметна в объявлениях не на первом и не последнем этаже. Самая низкая средняя стоимость наблюдается на первом этаже

# %% [markdown]
# ##### Влияние дня недели на стоимость

# %%
data_weekday = data.pivot_table(values='last_price_good', index ='weekday',aggfunc='median')
data_weekday.plot(kind='bar')
plt.ylabel('median_price')
data_weekday
# Out:
#          last_price_good
# weekday
# 0               4.650000
# 1               4.714595
# 2               4.700000
# 3               4.650000
# 4               4.580000
# 5               4.550000
# 6               4.550000

# %% [markdown]
# Зависимость между днем, когда было опубликовано объявление и средней стоимостью квартиры, крайне не велика. Наиболее высокая средняя стоимость в объявлениях, опубликованных во вторник.

# %% [markdown]
# ##### Влияние месяца на стоимость

# %%
data_month = data.pivot_table(values='last_price_good', index ='month',aggfunc='median')
data_month.plot(kind='bar')
plt.ylabel('median_price')
data_month
# Out:
#        last_price_good
# month
# 1                 4.60
# 2                 4.65
# 3                 4.67
# 4                 4.80
# 5                 4.50
# 6                 4.40
# 7                 4.65
# 8                 4.60
# 9                 4.70
# 10                4.57
# 11                4.70
# 12                4.70

# %% [markdown]
# Схожая ситуация наблюдается и при просмотре данных о влиянии месяца публикации на стоимость жилья. Влияние не высокое. Самая большая средняя стоимость фиксируется в апреле, самая низкая - в январе и июне

# %% [markdown]
# ##### Влияние года на стоимость

# %%
data_year = data.pivot_table(values='last_price_good', index ='year',aggfunc='median')
data_year.plot(kind='bar')
plt.ylabel('median_price')
data_year
# Out:
#       last_price_good
# year
# 2014           7.6400
# 2015           5.3000
# 2016           4.5000
# 2017           4.5000
# 2018           4.5875
# 2019           5.0500

# %% [markdown]
# После 2014 года наблюдается резкое падение в средней стоимости квартир из объявлений. Самые низкая средняя цена фиксируется в 2016 и 2017 годах. В два следующих года наблюдается постепенный рост.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Для категории этажа, дня, месяца и года продажи нужно построить barplot или гистограмму рассчитав среднее значение или медиану. После этого необходимо написать о зависимости цены от этих параметров
#
#     https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Гистограмы построил, основную информацию по переменным вывел. Про влияние на стоимость написал выше по итогу нахождения коэффициентов корреляции.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v3:</b>
# <br>Ты построил просто гистограммы, а нужно сначала рассчитать среднее или медиану. Также нужно изучить не этаж, а категорию этажа
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v4:</b>
# <br>Теперь все верно! Ещё тут можно использовать для визуализации pairplot из библиотеки seaborn
#
#     https://seaborn.pydata.org/generated/seaborn.pairplot.html
# </div>

# %% [markdown]
# #### Подсчет средней цены квадратного метра

# %% [markdown]
# Найдем топ-10 населенных пунктов по кол-ву объявлений

# %%
data.pivot_table(values='price_metr_good', index='good_locality_name', aggfunc=('count','median')).sort_values(by='count', ascending=False).head(10)
# Out:
#                     count      median
# good_locality_name
# санкт-петербург     15580  104.664414
# мурино                587   86.119403
# кудрово               470   95.791451
# шушары                439   76.829268
# всеволожск            396   65.789474
# пушкин                365   99.987179
# колпино               337   74.725275
# парголово             326   91.780224
# гатчина               306   67.860569
# выборг                235   58.307692

# %% [markdown]
# Топ-3 наиболее популряных населенных пункта: Санкт-Петербург, Мурино и Кудрово
#
# Топ-3 населенных пункта с самой высокой средней стоимостью квадратного метра среди 10 наиболее популярных: Санкт-Петербург, Пушкино, Кудрово
#
# Топ-3 населенных пункта с самой низкой средней стоимость за квадратный метр среди 10 наиболее популярных: Всеволожск, Гатчина, Колпино

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Тут нужно выделить населённые пункты с максимальной и минимальной ценой из того списка топ10 что ты выводишь самым первым
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Исправил
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v3:</b>
# <br>Всё верно! Как вариант, тут вместо таблицы можно построить гистограмму, так будет более наглядно)
# </div>

# %% [markdown]
# #### Подсчет средней цены для каждого километра отдаления от центра Санкт-Петербурга

# %%
data[data['locality_name']=='санкт-петербург'].pivot_table(values='last_price_good',index='cityCenters_nearest_km', aggfunc='median')
# Out:
#                         last_price_good
# cityCenters_nearest_km
# 0.0                           15.900000
# 1.0                           11.225000
# 2.0                           10.000000
# 3.0                            8.409000
# 4.0                            9.190000
# 5.0                            9.400000
# 6.0                            8.787819
# 7.0                            7.797500
# 8.0                            7.445000
# 9.0                            5.350500
# 10.0                           5.025000
# 11.0                           5.095000
# 12.0                           4.950000
# 13.0                           5.200000
# 14.0                           4.875000
# 15.0                           4.900000
# 16.0                           4.799750
# 17.0                           4.574160
# 18.0                           4.300000
# 19.0                           4.500000
# 20.0                           5.550000
# 21.0                           5.289476
# ...

# %% [markdown]
# Кажется, что таблица не очень наглядна, надо построить график!

# %%
data_spb = data[data['good_locality_name'] == 'санкт-петербург']
data_spb.plot(kind = 'scatter', y='last_price_good', x='cityCenters_nearest_km', alpha=0.05)
plt.ylim(0,15)
plt.xlim(0,30)
# Out:
# (0.0, 30.0)

# %% [markdown]
# Таблица была нагляднее, попробуем другой график

# %%
data_km = data_spb.pivot_table(values='last_price_good',index='cityCenters_nearest_km', aggfunc='median')
data_km.plot()
plt.xlim(0,30)
# Out:
# (0.0, 30.0)

# %% [markdown]
# Отличнно, теперь мы видим как сильно снижается стоимость в зависимости от удаления от центра. Самое резкое снижение происходит от 0 до 10 км, далее мы видим плато с небольшим пиком в районе 20 км, падением после 24 км и очередным пиком на отметке в 26км
#
# Проверим зависимость на основании коэффициента корреляции

# %%
data_spb.corr()['last_price_good'].sort_values(ascending=False)
# Out:
# last_price_good           1.000000
# last_price                1.000000
# total_area                0.771991
# price_metr                0.722834
# price_metr_good           0.722834
# living_area               0.687188
# kitchen_area              0.614429
# rooms                     0.478622
# ceiling_height            0.468176
# ponds_around3000          0.222559
# parks_around3000          0.212096
# days_exposition           0.144852
# total_images              0.117369
# day                       0.010214
# balcony                   0.007886
# month                     0.007054
# weekday                   0.000669
# open_plan                -0.001073
# floor                    -0.010908
# airports_nearest         -0.016827
# parks_nearest            -0.021056
# studio                   -0.039002
# year                     -0.054012
# floors_total             -0.075604
# ponds_nearest            -0.130382
# cityCenters_nearest_km   -0.375617
# cityCenters_nearest      -0.375863
# ...

# %% [markdown]
# Наблюдается отрицательная связь на уровне 0,26. Связь очевидна!

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Отличный анализ 👍
# </div>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# В результате исследования нам удалосось:
#
# <b> Провести предобработку данных</b>: избавились от пропущенных значений, аномалий и неявных дубликатов, там где это было возможно. Для этого мы рассмотрели каждую из переменных, входящую в датасет. Также мы добавили несеолько новых столбцов для последующего анализа и поменяли тип переменной там, где это было необходимо.
#
# <b> Провести исследователский анализ </b> в рамках которого мы описали каждую из имеющихся переменных, вывели типичную квартиру выборки, нашли факторы, которые оказывают наиболее сильное влияние на стоимость квартиры (общая площадь - наивысшее положительное влияние, удаленность от центра - наивысшее отрицательное влияние). Для этого мы рассмотрели каждую отдельную переменную, построили гистограмы / скатерплоты, вывели описательные статистики, там где было необходимо нашли коэффициенты корреляции.
#
# Также мы изучили как быстро продавались квартиры. В половине случаев квартира продавалась по прошествию 95 дней, тем не менее были и куда более длительные объявления. Далее мы расчитали среднюю цену в 10 наиболее популярных населенных пунктах (на первом месте оказался Санкт-Петербург). После этого мы рассмотрели как меняется цена на объекты в Санкт-Петербурге в зависимости от удаленности от центра. Результат был очевиден, с удаленностью от центра цена снижалась.
#
# <b> Типичная квартира в выборке </b>
#
# Продается 1-комнатная квартира на втором этаже 5-ти этажного жилого дома. Площадь - 45 метров, из них 6 метров отводится кухне и 18 метров на жилую площадь. Доступная цена - 4,5 миллиона рублей. Потолки 2,5 метра.
#
# Расстояние до центра города чуть больше 13 км. До ближайшего парка всего 441 метр. Улететь в другой город вы сможете, проделав путь чуть более 14,5 км.

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>Давай увеличим объем вывода, чтобы он получится более подробным. Хорошей практикой является написание в общем выводе всех твоих действий (кратко) по проекту. А после этого нужно написать общий вывод использую информацию из промежуточных выводов после каждого раздела. Твой вывод раскрывает для заказчика всю твою проделанную работу и за что он платит деньги, даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v3:</b>
# <br>Супер! Так гораздо лучше)
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b>
# <br>После всех внесённых правок, обязательно перепроверь общий вывод и промежуточные выводы и поправь их по необходимости
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Итоговый комментарий ревьюера v1:</b>
# <br>Ты хорошо потрудился, большая часть работы сделана, но остаётся внести следующие правки:
# <br>- написать короткий вывод после первичного просмотра данных
# <br>- изменить тип данных в столбце balcony
# <br>- отбросить аномальные значения (площадь квартиры, стоимость, количество комнат)
# <br>- построить график для столбца floors_total
# <br>- построить графики для дня недели и месяца публикации объявления
# <br>- корректно выполнить шаг 4.2
# <br>- доработать шаг 4.3
# <br>- поправить вывод в шаге 4.4
# <br>- дописать общий вывод
# <br>- поправить выводы там, где это необходимо
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Кажется, что все комментарии удалось учесть :)
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Итоговый комментарий ревьюера v3:</b>
# <br>Остаются три правки:
# <br>- изменить тип данных в столбце balcony
# <br>- доработать шаг 4.3
# <br>- поправить выводы там, где это необходимо
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Итоговый комментарий ревьюера v4:</b>
# <br>Все правки выполнены. Молодец!
# <br>Проделана огромная работа! У тебя подробные, понятные и логичные выводы, которые ты подкрепляешь фактами. Были использованы разные графики и способы, чтобы как можно более тщательно изучить данные и у тебя это получилось!
# <br>Я рад был поработать над проверкой твоей работы) В качестве дополнительного материала для изучения могу порекомендовать следующий ресурс:
#
# 	https://www.python-graph-gallery.com/
# <br>В нем содержится большая библиотека графиков с готовым кодом, который можно использовать при работе.
# <br>Поздравляю со сдачей проекта и желаю удачи в дальнейшем обучении! 😉
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [ ]  определены пропущенные значения
# - [ ]  заполнены пропущенные значения там, где это возможно
# - [ ]  есть пояснение, какие пропущенные значения обнаружены
# - [ ]  изменены типы данных
# - [ ]  есть пояснение, в каких столбцах изменены типы и почему
# - [ ]  устранены неявные дубликаты в названиях населённых пунктов
# - [ ]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [ ]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [ ]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [ ]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [ ]  посчитано и добавлено в таблицу: год публикации объявления
# - [ ]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [ ]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [ ]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [ ]  построены гистограммы для каждого параметра
# - [ ]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [ ]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [ ]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [ ]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [ ]  в каждом этапе есть промежуточные выводы
# - [ ]  есть общий вывод
